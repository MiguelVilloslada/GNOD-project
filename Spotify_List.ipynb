# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
import getpass

# %%
client_id=str(getpass.getpass('enter your client id?'))
client_secret=str(getpass.getpass('enter your client secret?'))
# Out:
# enter your client id?········
# enter your client secret?········

# %%
#Initialize SpotiPy with user credentias
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(
    client_id=client_id,
    client_secret=client_secret))

# %%
playlist = sp.user_playlist_tracks("Kroschi", "7xmpNYZ15D6b43BHzYQCLt")

# %%
# Function:
        # input: username, playlist_id
        # output: ALL the songs, not just 100
def get_playlist_tracks(username, playlist_id):
    results = sp.user_playlist_tracks(username, playlist_id)
    tracks = results['items']
    while results['next']:
        # print(results['next'])
        results = sp.next(results)
        tracks.extend(results['items'])
    return tracks

# %%
# store all the tracks in a variable
all_tracks = get_playlist_tracks('Kroschi', "7xmpNYZ15D6b43BHzYQCLt")
len(get_playlist_tracks('Kroschi', "7xmpNYZ15D6b43BHzYQCLt"))
# Out:
# 1711

# %%
# get artist name form songs
def get_artists_from_track(track):
    return [artist["name"] for artist in track["artists"]]

# %%
tracks_from_playlist = get_playlist_tracks('Kroschi', "7xmpNYZ15D6b43BHzYQCLt")

# %%
[get_artists_from_track(track['track']) for track in tracks_from_playlist]
# Out:
# [['Yiruma'],
#  ['Alexis Ffrench'],
#  ['Frédéric Chopin', 'Lucas Blondeel'],
#  ['Ludwig van Beethoven', 'Alfred Blanariu'],
#  ['Shinya Kiyozuka'],
#  ['Robert Schumann', "Rachel Porter's All Female Symphonic Orchestra"],
#  ['Claude Debussy', 'Zuri Lux'],
#  ['Clint Mansell'],
#  ['Franz Liszt', 'Vincenzo Cresti'],
#  ['Max Richter'],
#  ['Oscar Pascasio'],
#  ['Georg Nielsen', 'Enzo Orefice'],
#  ['Nils Frahm'],
#  ['Frédéric Chopin', 'Lucas Blondeel'],
#  ['Claude Debussy', 'Jordi Castellà'],
#  ['Giovanni Allevi'],
#  ['Javi Lobe'],
#  ['The City of Prague Philharmonic Orchestra'],
#  ['Franz Liszt', 'Alfred Blanariu'],
#  ['Maurice Ravel', 'Lucas Blondeel'],
#  ['Piano Novel'],
#  ['Nicole Sinman'],
#  ['Erik Satie', 'Alfred Blanariu'],
#  ['Ludovico Einaudi'],
#  ['The Echelon Effect'],
#  ['Nylonwings'],
#  ['Isaac Shepard'],
#  ['Helen Jane Long'],
#  ['Johannes Brahms', 'Zuri Lux'],
#  ['Roberto Cacciapaglia'],
#  ['Laura Christie Wall', 'Ron Adelaar'],
# ...

# %%
playlist=sp.user_playlist_tracks("Kroschi", "7xmpNYZ15D6b43BHzYQCLt")
songs = {
  track["track"]["id"]: [track["track"]["name"], 
  track["track"]["artists"][0]["name"]] 
  for track in playlist["items"]
}
